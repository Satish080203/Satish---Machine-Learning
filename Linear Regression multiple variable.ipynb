# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_excel("multi.xlsx")
df
# Out:
#    area  bedroom  age   price
# 0  1500      3.0   10  500000
# 1  2000      2.0   15  650000
# 2  3000      NaN   16  450000
# 3  3500      5.0   20  400000
# 4  5000      4.0   35  550000

# %%
import math
median_bedroom=math.floor(df.bedroom.median())
median_bedroom
# Out:
# 3

# %%
df.bedroom=df.bedroom.fillna(median_bedroom)
df.bedroom
# Out:
# 0    3.0
# 1    2.0
# 2    3.0
# 3    5.0
# 4    4.0
# Name: bedroom, dtype: float64

# %%
df
# Out:
#    area  bedroom  age   price
# 0  1500      3.0   10  500000
# 1  2000      2.0   15  650000
# 2  3000      3.0   16  450000
# 3  3500      5.0   20  400000
# 4  5000      4.0   35  550000

# %%
reg=LinearRegression()
reg
# Out:
# LinearRegression()

# %%
reg.fit(df[['area','bedroom','age']],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  -133.71805441, -50453.42126958,  22093.98186315])

# %%
reg.intercept_
# Out:
# 658491.3437757625

# %%
reg.predict([[3250,5,5]])
# Out:
# D:\jupyter\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([82110.46990932])

# %%
reg.predict([[6000,5,10]])
# Out:
# D:\jupyter\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-175144.27040396])

# %%
plt.plot(df.area,reg.predict(df[['area','bedroom','age']]),color='blue')
plt.show()
